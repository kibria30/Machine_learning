# %%
import pandas as pd

# %%
df = pd.read_csv('deshimula_all_reviews_new.csv')
df.content.to_list()[:5]
# Out:
# ['I\'ve been working at $parktech (under Betopi@ Group) as a developer and team lead for about 14 months now. I know a lot of people have negative opinions about our company, some ex-employees have left tough reviews here too. And honestly? Every workplace has its ups and downs. But I also feel like the good parts often get skipped in the conversation, so I wanted to share my perspective.\n$parktech is genuinely beginner-friendly in a way most Bangladeshi tech companies aren\'t. While everyone else hunts for "experienced, mature" engineers, we actually encourage freshers to join and grow with us. I\'ve personally seen cases where we trained developers for 2–3 months after they joined, something rare here. Most local companies see shaky performance and show the door immediately. We\'ve never fired anyone just for underperforming. Instead, we give space to learn, make mistakes, and improve. (I once had a junior dev who accidentally deployed to production on day three, instead of panic-
# ...

# %%
df.shape
# Out:
# (2152, 10)

# %%
df.head()
# Out:
#    id                                       company_name  developer_role  \
# 0   1  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
# 1   2  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
# 2   3  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
# 3   4  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
# 4   5  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
#
#                 date                                              title  \
# 0  February 04, 2026  Behind the Noise: Freshers Get Real Wings Here...
# 1   January 11, 2026  My Personal Experience at Sp@rkTech Agency (Pa...
# 2   January 10, 2026                   Hard Work + Smart Work = Success
# 3      June 10, 2025                                  Good for freshers
# 4      June 08, 2025  Supportive Work Environment with Strong Growth...
#
#                                              content  upvote  downvote  \
# ...

# %%
df_bs = df[df["company_name"]=="brain-station-23"]
df_bs.head()
# Out:
# Empty DataFrame
# Columns: [id, company_name, developer_role, date, title, content, upvote, downvote, comment_count, vibe]
# Index: []

# %%
df_company = pd.read_csv('deshimula_companies_new.csv')
df_company.head()
# Out:
#                                                 slug  dm_reviews
# 0  betopia-bdcalling-sparktech-softvence-sm-tech-...          87
# 1                                     technonext-ltd          81
# 2                                         optimizely          44
# 3                               mir-info-systems-ltd          42
# 4                                          therap-bd          42

# %%
df_company.shape
# Out:
# (716, 2)

# %%
sum(df_company.dm_reviews[:650])
# Out:
# 2390
