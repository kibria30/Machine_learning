# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../deshimula_all_reviews.csv')
df.head()
# Out:
#    id                                       company_name  developer_role  \
# 0   1  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
# 1   2  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
# 2   3  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
# 3   4  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
# 4   5  Betopia / BdCalling / Sparktech / Softvence / ...             NaN
#
#                 date                                              title  \
# 0  February 04, 2026  Behind the Noise: Freshers Get Real Wings Here...
# 1   January 11, 2026  My Personal Experience at Sp@rkTech Agency (Pa...
# 2   January 10, 2026                   Hard Work + Smart Work = Success
# 3      June 10, 2025                                  Good for freshers
# 4      June 08, 2025  Supportive Work Environment with Strong Growth...
#
#                                              content  upvote  downvote  \
# ...

# %%
sentiment_df.shape
# Out:
# (2552, 2)

# %%
sentiment_df = df[['content', 'vibe']]
sentiment_df.vibe.value_counts()
# Out:
# vibe
# Negative    1980
# Positive     289
# Mixed        283
# Name: count, dtype: int64

# %%
sentiment_df.to_csv('sentiment_df.csv', index=False)

# %%
sentiment_df.head(10)
# Out:
#                                              content      vibe
# 0  I've been working at $parktech (under Betopi@ ...  Positive
# 1  I have seen many negative comments about Betop...  Positive
# 2  Betopi@ / BdCa11ing / $parktech / S0ftv3nce / ...  Positive
# 3  Pros\nThis company is good for freshers who ha...  Positive
# 4  Pros:\nSupportive Management: Encouraging and ...  Positive
# 5  আজ ৫ ই আগষ্ট। বাংলাদেশে সরকারি সাধারণ ছুটি। সব...  Negative
# 6  কী আর বলব এদের নিয়ে! আমি এখানে আড়াই বছরেরও ব...  Negative
# 7  বাংলাদেশ শ্রম আইন, ২০০৬ অনুযায়ী প্রতিটি প্রতিষ...  Negative
# 8  $oftvence-এ ইনক্রিমেন্ট নিতে গিয়ে বুঝলাম, একজ...  Negative
# 9  $oftvence-এ হঠাৎ করেই WhatsApp গ্রুপে একটি নোট...  Negative

# %%
sentiment_top_10 = sentiment_df.head(10)
sentiment_top_10.to_csv('sentiment_top_10.csv', index=False)
